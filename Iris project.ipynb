# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
Iris= pd.read_csv(r'D:\ds notes\4,5-jan\4th,5th\4th,5th\IRIS DATASET _ ADVANCE VISUALIZATION _ EDA 2\Iris.csv')

# %%
Iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
Iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
Iris.Species=Iris.Species.astype('category')

# %%
Iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    category
# dtypes: category(1), float64(4), int64(1)
# memory usage: 6.3 KB

# %%
Iris.shape
# Out:
# (150, 6)

# %%
Iris.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
Iris.isnull().any()
# Out:
# Id               False
# SepalLengthCm    False
# SepalWidthCm     False
# PetalLengthCm    False
# PetalWidthCm     False
# Species          False
# dtype: bool

# %%
Iris.hist(figsize=(12,10))
# Out:
# array([[<AxesSubplot:title={'center':'Id'}>,
#         <AxesSubplot:title={'center':'SepalLengthCm'}>],
#        [<AxesSubplot:title={'center':'SepalWidthCm'}>,
#         <AxesSubplot:title={'center':'PetalLengthCm'}>],
#        [<AxesSubplot:title={'center':'PetalWidthCm'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
sns.countplot(data=Iris)
# Out:
# <AxesSubplot:ylabel='count'>

# %%
pd.crosstab(Iris['SepalLengthCm'], Iris['Species'])
# Out:
# Species        Iris-setosa  Iris-versicolor  Iris-virginica
# SepalLengthCm
# 4.3                      1                0               0
# 4.4                      3                0               0
# 4.5                      1                0               0
# 4.6                      4                0               0
# 4.7                      2                0               0
# 4.8                      5                0               0
# 4.9                      4                1               1
# 5.0                      8                2               0
# 5.1                      8                1               0
# 5.2                      3                1               0
# 5.3                      1                0               0
# 5.4                      5                1               0
# 5.5                      2                5               0
# 5.6                      0                5               1
# ...

# %%
pd.crosstab(Iris['SepalWidthCm'], Iris['Species'])
# Out:
# Species       Iris-setosa  Iris-versicolor  Iris-virginica
# SepalWidthCm
# 2.0                     0                1               0
# 2.2                     0                2               1
# 2.3                     1                3               0
# 2.4                     0                3               0
# 2.5                     0                4               4
# 2.6                     0                3               2
# 2.7                     0                5               4
# 2.8                     0                6               8
# 2.9                     1                7               2
# 3.0                     6                8              12
# 3.1                     5                3               4
# 3.2                     5                3               5
# 3.3                     2                1               3
# 3.4                     9                1               2
# 3.5                     6                0               0
# ...

# %%
pd.crosstab(Iris['PetalLengthCm'], Iris['Species'])
# Out:
# Species        Iris-setosa  Iris-versicolor  Iris-virginica
# PetalLengthCm
# 1.0                      1                0               0
# 1.1                      1                0               0
# 1.2                      2                0               0
# 1.3                      7                0               0
# 1.4                     12                0               0
# 1.5                     14                0               0
# 1.6                      7                0               0
# 1.7                      4                0               0
# 1.9                      2                0               0
# 3.0                      0                1               0
# 3.3                      0                2               0
# 3.5                      0                2               0
# 3.6                      0                1               0
# 3.7                      0                1               0
# ...

# %%
pd.crosstab(Iris['PetalWidthCm'], Iris['Species'])
# Out:
# Species       Iris-setosa  Iris-versicolor  Iris-virginica
# PetalWidthCm
# 0.1                     6                0               0
# 0.2                    28                0               0
# 0.3                     7                0               0
# 0.4                     7                0               0
# 0.5                     1                0               0
# 0.6                     1                0               0
# 1.0                     0                7               0
# 1.1                     0                3               0
# 1.2                     0                5               0
# 1.3                     0               13               0
# 1.4                     0                7               1
# 1.5                     0               10               2
# 1.6                     0                3               1
# 1.7                     0                1               1
# 1.8                     0                1              11
# ...

# %%
sns.countplot(data=Iris, x='Species')
# Out:
# <AxesSubplot:xlabel='Species', ylabel='count'>

# %%
sns.pairplot(Iris)

# %%
sns.distplot(Iris['SepalWidthCm'])
# Out:
# <AxesSubplot:xlabel='SepalWidthCm', ylabel='Density'>

# %%
Iris.hist(by='Species', column='SepalWidthCm', color='red')
# Out:
# array([[<AxesSubplot:title={'center':'Iris-setosa'}>,
#         <AxesSubplot:title={'center':'Iris-versicolor'}>],
#        [<AxesSubplot:title={'center':'Iris-virginica'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
sns.countplot(data=Iris, palette="Set3")
# Out:
# <AxesSubplot:ylabel='count'>

# %%
sns.barplot(data=Iris)
# Out:
# <AxesSubplot:>

# %%
Iris.drop('Id', axis=1, inplace=True)

# %%
Iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
sns.boxplot(data=Iris, '')
# Out:
#   File "C:\Users\dell ltitude5480\AppData\Local\Temp\ipykernel_7704\3188972847.py", line 1
#     sns.boxplot(data=Iris, 'Species')
#                                     ^
# SyntaxError: positional argument follows keyword argument

# %%
df_setosa = Iris.loc[Iris['Species']=='setosa']
df_virginica = Iris.loc[Iris['Species']=='virginica']
df_versicolor = Iris.loc[Iris['Species']=='versicolor']

# %%
Iris.tail()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica

# %%
sns.scatterplot(data=Iris,'Species')
# Out:
#   File "C:\Users\dell ltitude5480\AppData\Local\Temp\ipykernel_7704\2941813755.py", line 1
#     sns.scatterplot(data=Iris,'Species')
#                                        ^
# SyntaxError: positional argument follows keyword argument

# %%
sns.boxplot(x = 'Species', y = 'SepalWidthCm', data=Iris)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='SepalWidthCm'>

# %%
plt.hist(Iris[Iris.Species=='Iris-virginica'].SepalWidthCm)
# Out:
# (array([ 1.,  4.,  2., 12.,  2., 16.,  8.,  2.,  1.,  2.]),
#  array([2.2 , 2.36, 2.52, 2.68, 2.84, 3.  , 3.16, 3.32, 3.48, 3.64, 3.8 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(Iris[Iris.Species=='Iris-versicolor'].SepalWidthCm)
# Out:
# (array([ 1.,  2.,  6.,  4.,  3., 11.,  7., 11.,  3.,  2.]),
#  array([2.  , 2.14, 2.28, 2.42, 2.56, 2.7 , 2.84, 2.98, 3.12, 3.26, 3.4 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(Iris[Iris.Species=='Iris-virginica'].SepalWidthCm)
plt.hist(Iris[Iris.Species=='Iris-versicolor'].SepalWidthCm)
plt.hist(Iris[Iris.Species=='Iris-setosa'].SepalWidthCm)

plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.hist(Iris[Iris.Species=='Iris-virginica'].PetalWidthCm)
plt.hist(Iris[Iris.Species=='Iris-versicolor'].PetalWidthCm)
plt.hist(Iris[Iris.Species=='Iris-setosa'].PetalWidthCm)

plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.hist(Iris[Iris.Species=='Iris-virginica'].SepalLengthCm)
plt.hist(Iris[Iris.Species=='Iris-versicolor'].SepalLengthCm)
plt.hist(Iris[Iris.Species=='Iris-setosa'].SepalLengthCm)

plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.hist(Iris[Iris.Species=='Iris-virginica'].PetalLengthCm)
plt.hist(Iris[Iris.Species=='Iris-versicolor'].PetalLengthCm)
plt.hist(Iris[Iris.Species=='Iris-setosa'].PetalLengthCm)

plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
sns.kdeplot(Iris.PetalLengthCm, Iris.PetalWidthCm, shade_lowest=True, cmap='Accent')
# Out:
# C:\Users\dell ltitude5480\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\dell ltitude5480\anaconda3\lib\site-packages\seaborn\distributions.py:1718: UserWarning: `shade_lowest` is now deprecated in favor of `thresh`. Setting `thresh=0`, but please update your code.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='PetalWidthCm'>

# %%
sns.lmplot(data=Iris, x='PetalLengthCm', y='PetalWidthCm', hue='Species')

# %%
sns.lmplot(data=Iris, x='PetalLengthCm', y='PetalWidthCm')###Positive Correlation

# %%
a =sns.FacetGrid(Iris, row='Species', col='SepalLengthCm', hue='SepalWidthCm')
a = a.map(plt.hist, 'SepalLengthCm')

# %%
Iris.hist(figsize=(20,30))
# Out:
# array([[<AxesSubplot:title={'center':'SepalLengthCm'}>,
#         <AxesSubplot:title={'center':'SepalWidthCm'}>],
#        [<AxesSubplot:title={'center':'PetalLengthCm'}>,
#         <AxesSubplot:title={'center':'PetalWidthCm'}>]], dtype=object)
